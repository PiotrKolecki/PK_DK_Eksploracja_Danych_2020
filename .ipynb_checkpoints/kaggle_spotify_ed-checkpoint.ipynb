# %%
from mpl_toolkits.mplot3d import Axes3D
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# data.csv may have more rows in reality, but we are only loading/previewing the first 1000 rows
df_data = pd.read_csv('./kaggle_data/data.csv', delimiter=',')
df_data_w_generes = pd.read_csv('./kaggle_data/data_w_genres.csv', delimiter=',')
df_data_by_artist = pd.read_csv('./kaggle_data/data_by_artist.csv', delimiter=',')
df_data_by_genres = pd.read_csv('./kaggle_data/data_by_genres.csv', delimiter=',')
df_data_by_year = pd.read_csv('./kaggle_data/data_by_year.csv', delimiter=',')

# %%
df_data.loc[df_data['artists'] == '[\'Metallica\']']

df_new = df_data.copy()

df_new = df_new.drop(columns=['id', 'acousticness', 'explicit', 'energy', 'release_date', 'mode', 'key'])
df_new.head(5)
# Out:
#                                     artists  danceability  duration_ms  \
# 0                       ['Carl Woitschach']         0.708       158648
# 1  ['Robert Schumann', 'Vladimir Horowitz']         0.379       282133
# 2                   ['Seweryn Goszczyński']         0.749       104300
# 3                      ['Francisco Canaro']         0.781       180760
# 4  ['Frédéric Chopin', 'Vladimir Horowitz']         0.210       687733
#
#    instrumentalness  liveness  loudness  \
# 0             0.563    0.1510   -12.428
# 1             0.901    0.0763   -28.454
# 2             0.000    0.1190   -19.924
# 3             0.887    0.1110   -14.734
# 4             0.908    0.0980   -16.829
#
#                                             name  popularity  speechiness  \
# 0                    Singende Bataillone 1. Teil           0       0.0506
# 1       Fantasiestücke, Op. 111: Più tosto lento           0       0.0462
# 2                 Chapter 1.18 - Zamek kaniowski           0       0.9290
# 3  Bebamos Juntos - Instrumental (Remasterizado)           0       0.0926
# 4    Polonaise-Fantaisie in A-Flat Major, Op. 61           1       0.0424
#
#      tempo  valence  year
# 0  118.469   0.7790  1928
# 1   83.972   0.0767  1928
# 2  107.177   0.8800  1928
# 3  108.003   0.7200  1928
# 4   62.149   0.0693  1928

# %%
#df_new.corr()

# %%
df_new.drop(df_new[df_new.duration_ms < 60000].index, inplace=True)
print(df_data.shape[0])
print(df_new.shape[0])
# Out:
# 169909
# 168313

# %%
df_new.drop(df_new[df_new.popularity == 0].index, inplace=True)
print(df_data.shape[0])
print(df_new.shape[0])
# Out:
# 169909
# 141730

# %%
x = df_new.index
y = df_new.sort_values(by='duration_ms')['duration_ms']
plt.scatter(x, y, alpha=0.3, cmap='viridis')

# %%
x = df_new['duration_ms']
y = df_new.year
plt.xlim(0, 1000000)
plt.scatter(x, y, marker='.', alpha=0.1, cmap='viridis')

# %%
x = df_data.duration_ms
x = list(map(lambda a: a/1000, x))
y = df_data.popularity
plt.xlim(0, 100000)
plt.scatter(x, y, marker='.', alpha=0.1, cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-b8ec063ff45e> in <module>
#       3 y = df_data.popularity
#       4 plt.xlim(0, 100000)
# ----> 5 plt.scatter(x, y, marker='.', alpha=0.1, cmap='viridis')
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2809         verts=cbook.deprecation._deprecated_parameter,
#    2810         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2811     __ret = gca().scatter(
#    2812         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2813         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4369         # Process **kwargs to handle aliases, conflicts with explicit kwargs:
#    4370
# -> 4371         self._process_unit_info(xdata=x, ydata=y, kwargs=kwargs)
#    4372         x = self.convert_xunits(x)
#    4373         y = self.convert_yunits(y)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2071             return kwargs
#    2072
# -> 2073         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
#    2074         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2075         return kwargs
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\axes\_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2054                 # We only need to update if there is nothing set yet.
#    2055                 if not axis.have_units():
# -> 2056                     axis.update_units(data)
#    2057
#    2058             # Check for units in the kwargs, and if present update axis
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\axis.py in update_units(self, data)
#    1508         if *data* is registered for unit conversion.
#    1509         """
# -> 1510         converter = munits.registry.get_converter(data)
#    1511         if converter is None:
#    1512             return False
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\units.py in get_converter(self, x)
#     213                 pass
#     214         try:  # If cache lookup fails, look up based on first element...
# --> 215             first = cbook.safe_first_element(x)
#     216         except (TypeError, StopIteration):
#     217             pass
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\matplotlib\cbook\__init__.py in safe_first_element(obj)
#    1648         except TypeError:
#    1649             pass
# -> 1650         raise RuntimeError("matplotlib does not support generators "
#    1651                            "as input")
#    1652     return next(iter(obj))
#
# RuntimeError: matplotlib does not support generators as input
